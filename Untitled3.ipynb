# %%
age="45"
print(type(age))
# Out:
# <class 'str'>

# %%
s="SPIDERMAN DAY"
print(s.find("D"))
# Out:
# 3

# %%
print(s.rfind("A"))
# Out:
# 11

# %%
print(s.count("A"))
# Out:
# 2

# %%
print(s.startswith("SI"))
# Out:
# False

# %%
print(s.endswith("AY"))
# Out:
# True

# %%
print(s.lower())
# Out:
# spiderman day

# %%
print(s.upper())
# Out:
# SPIDERMAN DAY

# %%
print(s.replace("DAY","month"))
# Out:
# SPIDERMAN month

# %%
A=" A V E N G E R D A Y "
stripped_num=A.strip()
print(stripped_num)
# Out:
# A V E N G E R D A Y

# %%
A=" A V E N G E R D A Y "
stripped_num=A.strip()
print(stripped_num)
no_space_=A.replace(" ","")
print(no_space_)
# Out:
# A V E N G E R D A Y
# AVENGERDAY
